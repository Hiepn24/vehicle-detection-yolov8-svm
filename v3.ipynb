# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install ultralytics opencv-python numpy

from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # Tạo model
model.train(data="/content/drive/MyDrive/Colab Notebooks/v3/data.yaml", epochs=50, imgsz=640)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO("/content/runs/detect/train4/weights/best.pt")

results = model("https://xehay.vn/uploads/images/2020/1/Xehay-ANTD-Cop-030120-4.jpg")  # Chạy nhận diện trên một ảnh
# results = model("/content/drive/MyDrive/Colab Notebooks/v2/test/images/modified_img1_46_jpg.rf.999cdd0b8c7501e0ca83b7bd3fe90659.jpg")  # Chạy nhận diện trên một ảnh
results[0].show()
# Out:
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
#
# ...
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# ...

# %%
import shutil

shutil.make_archive('runs', 'zip', 'runs')
from google.colab import files

files.download('runs.zip')
# Out:
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# ...
